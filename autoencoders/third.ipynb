# %%
import torch
import torch.optim

#import CIFAR_v2 as C
import CIFAR_v3 as C

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = C.CIFARAutoEncoderV3(512).to(device)
#model = C.CIFARAutoEncoderV2(512).to(device)
epoch_enc = 0
epoch_dec = 0
train_load, test_load = C.get_cifar_loaders(download=False)
opt_enc = torch.optim.Adam(model.classifier.parameters(), lr=0.01)
opt_dec = torch.optim.Adam(model.decoder.parameters(), lr=0.001)

# %%
for _ in range(15):
    epoch_enc += 1
    C.train_encoder(model, device, train_load, opt_enc, epoch_enc)
    C.test_encoder(model, device, test_load)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.295967
# Train Epoch: 1 [4000/50000 (8%)]	Loss: 2.296572
# Train Epoch: 1 [8000/50000 (16%)]	Loss: 2.304800
# Train Epoch: 1 [12000/50000 (24%)]	Loss: 2.320714
# Train Epoch: 1 [16000/50000 (32%)]	Loss: 2.300527
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 2.293327
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0575879d565f> in <module>()
#       1 for _ in range(15):
#       2     epoch_enc += 1
# ----> 3     C.train_encoder(model, device, train_load, opt_enc, epoch_enc)
#       4     C.test_encoder(model, device, test_load)
#
# ~\Documents\HybridAnimalAutoencoders\autoencoders\CIFAR_v3.py in train_encoder(model, device, train_loader, optimizer, epoch)
#     152 def train_encoder(model, device, train_loader, optimizer, epoch):
#     153     model.train()
# --> 154     for batch_idx, (data, target) in enumerate(train_loader):
#     155         data, target = data.to(device), target.to(device)
#     156         optimizer.zero_grad()
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torchvision\datasets\cifar.py in __getitem__(self, index)
#     122
#     123         if self.transform is not None:
# --> 124             img = self.transform(img)
#     125
#     126         if self.target_transform is not None:
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, pic)
#      89             Tensor: Converted image.
#      90         """
# ---> 91         return F.to_tensor(pic)
#      92
#      93     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\functional.py in to_tensor(pic)
#      85     else:
#      86         nchannel = len(pic.mode)
# ---> 87     img = img.view(pic.size[1], pic.size[0], nchannel)
#      88     # put it from HWC to CHW format
#      89     # yikes, this transpose takes 80% of the loading time/CPU
#
# KeyboardInterrupt:

# %%
for _ in range(50):
    epoch_dec += 1
    C.train_decoder(model, device, train_load, opt_dec, epoch_dec)
    C.test_decoder(model, device, test_load)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 0.694797
# Train Epoch: 1 [4000/50000 (8%)]	Loss: 0.653288
# Train Epoch: 1 [8000/50000 (16%)]	Loss: 0.666192
# Train Epoch: 1 [12000/50000 (24%)]	Loss: 0.650277
# Train Epoch: 1 [16000/50000 (32%)]	Loss: 0.663539
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 0.644325
# Train Epoch: 1 [24000/50000 (48%)]	Loss: 0.656257
# Train Epoch: 1 [28000/50000 (56%)]	Loss: 0.665933
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 0.663254
# Train Epoch: 1 [36000/50000 (72%)]	Loss: 0.645884
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 0.645601
# Train Epoch: 1 [44000/50000 (88%)]	Loss: 0.667066
# Train Epoch: 1 [48000/50000 (96%)]	Loss: 0.656353
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.645141
# Train Epoch: 2 [4000/50000 (8%)]	Loss: 0.651033
# Train Epoch: 2 [8000/50000 (16%)]	Loss: 0.655078
# Train Epoch: 2 [12000/50000 (24%)]	Loss: 0.651039
# Train Epoch: 2 [16000/50000 (32%)]	Loss: 0.656460
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 0.636734
# Train Epoch: 2 [24000/50000 (48%)]	Loss: 0.637937
# Train Epoch: 2 [28000/50000 (56%)]	Loss: 0.655609
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 0.649395
# Train Epoch: 2 [36000/50000 (72%)]	Loss: 0.646769
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 0.651550
# Train Epoch: 2 [44000/50000 (88%)]	Loss: 0.643034
# Train Epoch: 2 [48000/50000 (96%)]	Loss: 0.665625
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.622593
# Train Epoch: 3 [4000/50000 (8%)]	Loss: 0.624564
# Train Epoch: 3 [8000/50000 (16%)]	Loss: 0.633968
# Train Epoch: 3 [12000/50000 (24%)]	Loss: 0.633362
# Train Epoch: 3 [16000/50000 (32%)]	Loss: 0.635590
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 0.627913
# Train Epoch: 3 [24000/50000 (48%)]	Loss: 0.631508
# Train Epoch: 3 [28000/50000 (56%)]	Loss: 0.640726
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 0.649881
# Train Epoch: 3 [36000/50000 (72%)]	Loss: 0.645255
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 0.647628
# Train Epoch: 3 [44000/50000 (88%)]	Loss: 0.644671
# Train Epoch: 3 [48000/50000 (96%)]	Loss: 0.641608
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.645883
# Train Epoch: 4 [4000/50000 (8%)]	Loss: 0.628519
# Train Epoch: 4 [8000/50000 (16%)]	Loss: 0.611152
# Train Epoch: 4 [12000/50000 (24%)]	Loss: 0.641073
# Train Epoch: 4 [16000/50000 (32%)]	Loss: 0.647956
# Train Epoch: 4 [20000/50000 (40%)]	Loss: 0.649943
# Train Epoch: 4 [24000/50000 (48%)]	Loss: 0.626212
# Train Epoch: 4 [28000/50000 (56%)]	Loss: 0.672281
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 0.635733
# Train Epoch: 4 [36000/50000 (72%)]	Loss: 0.653104
# Train Epoch: 4 [40000/50000 (80%)]	Loss: 0.657212
# Train Epoch: 4 [44000/50000 (88%)]	Loss: 0.631127
# Train Epoch: 4 [48000/50000 (96%)]	Loss: 0.662614
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.630425
# Train Epoch: 5 [4000/50000 (8%)]	Loss: 0.641121
# Train Epoch: 5 [8000/50000 (16%)]	Loss: 0.641045
# Train Epoch: 5 [12000/50000 (24%)]	Loss: 0.609318
# Train Epoch: 5 [16000/50000 (32%)]	Loss: 0.603431
# Train Epoch: 5 [20000/50000 (40%)]	Loss: 0.634962
# Train Epoch: 5 [24000/50000 (48%)]	Loss: 0.633794
# Train Epoch: 5 [28000/50000 (56%)]	Loss: 0.621634
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 0.630124
# Train Epoch: 5 [36000/50000 (72%)]	Loss: 0.633882
# Train Epoch: 5 [40000/50000 (80%)]	Loss: 0.617878
# Train Epoch: 5 [44000/50000 (88%)]	Loss: 0.623230
# Train Epoch: 5 [48000/50000 (96%)]	Loss: 0.618025
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.603423
# Train Epoch: 6 [4000/50000 (8%)]	Loss: 0.621506
# Train Epoch: 6 [8000/50000 (16%)]	Loss: 0.636730
# Train Epoch: 6 [12000/50000 (24%)]	Loss: 0.638019
# Train Epoch: 6 [16000/50000 (32%)]	Loss: 0.634088
# Train Epoch: 6 [20000/50000 (40%)]	Loss: 0.640671
# Train Epoch: 6 [24000/50000 (48%)]	Loss: 0.621063
# Train Epoch: 6 [28000/50000 (56%)]	Loss: 0.610301
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 0.651593
# Train Epoch: 6 [36000/50000 (72%)]	Loss: 0.620872
# Train Epoch: 6 [40000/50000 (80%)]	Loss: 0.639030
# Train Epoch: 6 [44000/50000 (88%)]	Loss: 0.634880
# Train Epoch: 6 [48000/50000 (96%)]	Loss: 0.598908
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.630781
# Train Epoch: 7 [4000/50000 (8%)]	Loss: 0.633784
# Train Epoch: 7 [8000/50000 (16%)]	Loss: 0.630811
# Train Epoch: 7 [12000/50000 (24%)]	Loss: 0.597494
# Train Epoch: 7 [16000/50000 (32%)]	Loss: 0.610554
# Train Epoch: 7 [20000/50000 (40%)]	Loss: 0.600249
# Train Epoch: 7 [24000/50000 (48%)]	Loss: 0.607105
# Train Epoch: 7 [28000/50000 (56%)]	Loss: 0.634797
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 0.606146
# Train Epoch: 7 [36000/50000 (72%)]	Loss: 0.629267
# Train Epoch: 7 [40000/50000 (80%)]	Loss: 0.630812
# Train Epoch: 7 [44000/50000 (88%)]	Loss: 0.632291
# Train Epoch: 7 [48000/50000 (96%)]	Loss: 0.640533
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.614652
# Train Epoch: 8 [4000/50000 (8%)]	Loss: 0.612938
# Train Epoch: 8 [8000/50000 (16%)]	Loss: 0.591080
# Train Epoch: 8 [12000/50000 (24%)]	Loss: 0.604880
# Train Epoch: 8 [16000/50000 (32%)]	Loss: 0.585073
# Train Epoch: 8 [20000/50000 (40%)]	Loss: 0.610450
# Train Epoch: 8 [24000/50000 (48%)]	Loss: 0.624642
# Train Epoch: 8 [28000/50000 (56%)]	Loss: 0.621170
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 0.599211
# Train Epoch: 8 [36000/50000 (72%)]	Loss: 0.646115
# Train Epoch: 8 [40000/50000 (80%)]	Loss: 0.631780
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-30584139d6f5> in <module>()
#       1 for _ in range(50):
#       2     epoch_dec += 1
# ----> 3     C.train_decoder(model, device, train_load, opt_dec, epoch_dec)
#       4     C.test_decoder(model, device, test_load)
#
# ~\Documents\HybridAnimalAutoencoders\autoencoders\CIFAR_v2.py in train_decoder(model, device, train_loader, optimizer, epoch)
#     127         loss = F.binary_cross_entropy(output, data)
#     128         loss.backward()
# --> 129         optimizer.step()
#     130         if batch_idx % 200 == 0:
#     131             print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
#
# ~\Anaconda3\lib\site-packages\torch\optim\adam.py in step(self, closure)
#      91
#      92                 # Decay the first and second moment running average coefficient
# ---> 93                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      94                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      95                 if amsgrad:
#
# KeyboardInterrupt:

# %%
C.show_true_and_recreated_imgs(model, train_load, device)

# %%
C.show_transition(model, train_load, device)
