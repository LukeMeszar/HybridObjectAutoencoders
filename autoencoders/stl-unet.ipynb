# %%
import torch
import torch.optim

import STL_v2 as S

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
model = S.STLAutoEncoder(128, 32).to(device)
epoch = 0
train_load, test_load = S.get_stl_loaders(download=False)
opt = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
for _ in range(50):
    S.train(model, device, train_load, opt, epoch)
    S.test(model, device, train_load)
    epoch += 1
# Out:
# Train Epoch: 3 [0/105000 (0%)]	Loss: 0.568881
# Train Epoch: 3 [4000/105000 (4%)]	Loss: 0.583667
# Train Epoch: 3 [8000/105000 (8%)]	Loss: 0.560538
# Train Epoch: 3 [12000/105000 (11%)]	Loss: 0.593700
# Train Epoch: 3 [16000/105000 (15%)]	Loss: 0.552815
# Train Epoch: 3 [20000/105000 (19%)]	Loss: 0.587653
# Train Epoch: 3 [24000/105000 (23%)]	Loss: 0.574378
# Train Epoch: 3 [28000/105000 (27%)]	Loss: 0.555530
# Train Epoch: 3 [32000/105000 (30%)]	Loss: 0.540936
# Train Epoch: 3 [36000/105000 (34%)]	Loss: 0.602630
# Train Epoch: 3 [40000/105000 (38%)]	Loss: 0.554946
# Train Epoch: 3 [44000/105000 (42%)]	Loss: 0.591407
# Train Epoch: 3 [48000/105000 (46%)]	Loss: 0.559140
# Train Epoch: 3 [52000/105000 (50%)]	Loss: 0.574360
# Train Epoch: 3 [56000/105000 (53%)]	Loss: 0.563849
# Train Epoch: 3 [60000/105000 (57%)]	Loss: 0.574591
# Train Epoch: 3 [64000/105000 (61%)]	Loss: 0.588310
# Train Epoch: 3 [68000/105000 (65%)]	Loss: 0.582664
# Train Epoch: 3 [72000/105000 (69%)]	Loss: 0.588959
# Train Epoch: 3 [76000/105000 (72%)]	Loss: 0.561320
# Train Epoch: 3 [80000/105000 (76%)]	Loss: 0.574191
# Train Epoch: 3 [84000/105000 (80%)]	Loss: 0.554522
# Train Epoch: 3 [88000/105000 (84%)]	Loss: 0.548446
# Train Epoch: 3 [92000/105000 (88%)]	Loss: 0.550499
# Train Epoch: 3 [96000/105000 (91%)]	Loss: 0.523027
# Train Epoch: 3 [100000/105000 (95%)]	Loss: 0.540045
# Train Epoch: 3 [104000/105000 (99%)]	Loss: 0.553340
# Train Epoch: 4 [0/105000 (0%)]	Loss: 0.585050
# Train Epoch: 4 [4000/105000 (4%)]	Loss: 0.573864
# Train Epoch: 4 [8000/105000 (8%)]	Loss: 0.557812
# Train Epoch: 4 [12000/105000 (11%)]	Loss: 0.563420
# Train Epoch: 4 [16000/105000 (15%)]	Loss: 0.542800
# Train Epoch: 4 [20000/105000 (19%)]	Loss: 0.536768
# Train Epoch: 4 [24000/105000 (23%)]	Loss: 0.574168
# Train Epoch: 4 [28000/105000 (27%)]	Loss: 0.552649
# Train Epoch: 4 [32000/105000 (30%)]	Loss: 0.533489
# Train Epoch: 4 [36000/105000 (34%)]	Loss: 0.580350
# Train Epoch: 4 [40000/105000 (38%)]	Loss: 0.545024
# Train Epoch: 4 [44000/105000 (42%)]	Loss: 0.564477
# Train Epoch: 4 [48000/105000 (46%)]	Loss: 0.608333
# Train Epoch: 4 [52000/105000 (50%)]	Loss: 0.584308
# Train Epoch: 4 [56000/105000 (53%)]	Loss: 0.553900
# Train Epoch: 4 [60000/105000 (57%)]	Loss: 0.578666
# Train Epoch: 4 [64000/105000 (61%)]	Loss: 0.572739
# Train Epoch: 4 [68000/105000 (65%)]	Loss: 0.587849
# Train Epoch: 4 [72000/105000 (69%)]	Loss: 0.565648
# Train Epoch: 4 [76000/105000 (72%)]	Loss: 0.576341
# Train Epoch: 4 [80000/105000 (76%)]	Loss: 0.600666
# Train Epoch: 4 [84000/105000 (80%)]	Loss: 0.561479
# Train Epoch: 4 [88000/105000 (84%)]	Loss: 0.570157
# Train Epoch: 4 [92000/105000 (88%)]	Loss: 0.539533
# Train Epoch: 4 [96000/105000 (91%)]	Loss: 0.576181
# Train Epoch: 4 [100000/105000 (95%)]	Loss: 0.574355
# Train Epoch: 4 [104000/105000 (99%)]	Loss: 0.559413
# Train Epoch: 5 [0/105000 (0%)]	Loss: 0.558145
# Train Epoch: 5 [4000/105000 (4%)]	Loss: 0.593769
# Train Epoch: 5 [8000/105000 (8%)]	Loss: 0.565548
# Train Epoch: 5 [12000/105000 (11%)]	Loss: 0.546189
# Train Epoch: 5 [16000/105000 (15%)]	Loss: 0.570437
# Train Epoch: 5 [20000/105000 (19%)]	Loss: 0.572857
# Train Epoch: 5 [24000/105000 (23%)]	Loss: 0.546193
# Train Epoch: 5 [28000/105000 (27%)]	Loss: 0.560005
# Train Epoch: 5 [32000/105000 (30%)]	Loss: 0.553739

# %%
S.show_true_and_recreated_imgs(model, train_load, device)

# %%
S.show_transition(model, train_load, device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-bf4de6627b5b> in <module>()
# ----> 1 S.show_transition(model, train_load, device)
#
# /home/grant/csci5922/project/STL_v2.py in show_transition(model, loader, device, n)
#     230         second_img = data[1].cpu().numpy()
#     231
# --> 232         encoded_vecs[0] = encoded[0]
#     233         encoded_vecs[n-1] = encoded[1]
#     234         for i in range(1, n-1):
#
# RuntimeError: The expanded size of the tensor (128) must match the existing size (192) at non-singleton dimension 0.  Target sizes: [128].  Tensor sizes: [192]

# %%
with open('stl_unet_model_1.model', 'wb') as f:
    torch.save(model, f)
